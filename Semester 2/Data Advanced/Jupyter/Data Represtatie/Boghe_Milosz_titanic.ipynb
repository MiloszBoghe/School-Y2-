# %%
# %config IPCompleter.greedy=True
import pandas as pd
import seaborn as sns
import matplotlib as mpl

# %%
data = pd.read_csv('titanic.csv')
data.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titan = sns.load_dataset('titanic')
titan.head(5).append(titan.tail(5))
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# ...

# %%
titan.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
len(titan)
# Out:
# 891

# %%
titan.survived
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
#opgave8
titan[["alive","alone","embark_town"]]
# Out:
#     alive  alone  embark_town
# 0      no  False  Southampton
# 1     yes  False    Cherbourg
# 2     yes   True  Southampton
# 3     yes  False  Southampton
# 4      no   True  Southampton
# ..    ...    ...          ...
# 886    no   True  Southampton
# 887   yes   True  Southampton
# 888    no  False  Southampton
# 889   yes   True    Cherbourg
# 890    no   True   Queenstown
#
# [891 rows x 3 columns]

# %%
#opgave9
titan[5:11]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 5     man        True  NaN   Queenstown    no   True
# 6     man        True    E  Southampton    no   True
# 7   child       False  NaN  Southampton    no  False
# 8   woman       False  NaN  Southampton   yes  False
# 9   child       False  NaN    Cherbourg   yes  False
# 10  child       False    G  Southampton   yes  False

# %%
#opgave10
titan[5:11][["survived","age"]]
# Out:
#     survived   age
# 5          0   NaN
# 6          0  54.0
# 7          0   2.0
# 8          1  27.0
# 9          1  14.0
# 10         1   4.0

# %%
#opgave11a
men_titan = titan[titan.sex=="male"]
len(men_titan)
# Out:
# 577

# %%
#opgave11b
titan.sex.value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
#opgave12
len(titan[titan["class"]=="First"])
# Out:
# 216

# %%
titan.sex.value_counts('%')
# Out:
# male      0.647587
# female    0.352413
# Name: sex, dtype: float64

# %%
#opgave14a
titan.embark_town.value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
#opgave14b
titan[titan.embark_town.isnull()]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone
# 61   woman       False    B         NaN   yes   True
# 829  woman       False    B         NaN   yes   True

# %%
#opgave14c
titan.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#opgave15
titan.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#opgave16
titan.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
print("%-10s %.2f"%("average:",titan.fare.mean()))
print("%-10s %.2f"%("mediaan:",titan.fare.median()))
print("%-10s %.2f"%("min:",titan.fare.min()))
print("%-10s %.2f"%("max:",titan.fare.max()))
print("%-10s %.2f"%("modus:",titan.fare.mode()))
print("%-10s %.2f"%("variantie:",titan.fare.var()))
print("%-10s %.2f"%("std:",titan.fare.std()))
print("%-10s %.2f"%("1st quartile:",titan.fare.quantile(0.25)))
print("%-10s %.2f"%("2nd quartile:",titan.fare.quantile(0.50)))
print("%-10s %.2f"%("3rd quartile:",titan.fare.quantile(0.75)))
# Out:
# average:   32.20
# mediaan:   14.45
# min:       0.00
# max:       512.33
# modus:     8.05
# variantie: 2469.44
# std:       49.69
# 1st quartile: 7.91
# 2nd quartile: 14.45
# 3rd quartile: 31.00
